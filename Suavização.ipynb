# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivynaaa/Colab_/blob/main/Suaviza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ivyna Alves
#Beatriz Leonara

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('einsteinRuido.jpg')
img2 = cv2.medianBlur(img, 5)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('tomografiaRuido.jpg')
ksize = (7,7)
img2 = cv2.blur(img, ksize)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=221x229>
